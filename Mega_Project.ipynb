# %% [markdown]
# <a href="https://colab.research.google.com/github/ifmankim/AdventureWorksDW2020---Power-BI/blob/main/Mega_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import libraries
import pandas as pd
import os
import matplotlib.pyplot as plt
import calendar

# %%
#get dataset from github
# !git clone https://github.com/ifmankim/Data-Science----Sales-Analytic.git
# Out:
# Cloning into 'Data-Science----Sales-Analytic'...
# remote: Enumerating objects: 25, done.
# remote: Counting objects: 100% (25/25), done.
# remote: Compressing objects: 100% (21/21), done.
# remote: Total 25 (delta 12), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (25/25), 2.52 MiB | 3.44 MiB/s, done.
# Resolving deltas: 100% (12/12), done.

# %%
#read all csv file
files = [file for file in os.listdir('/content/Data-Science----Sales-Analytic/dataset')]
for file in files:
  print(file)
# Out:
# Sales_March_2019.csv
# Sales_November_2019.csv
# Sales_December_2019.csv
# Sales_August_2019.csv
# Sales_June_2019.csv
# Sales_May_2019.csv
# Sales_October_2019.csv
# Sales_January_2019.csv
# Sales_April_2019.csv
# Sales_July_2019.csv
# Sales_September_2019.csv
# Sales_February_2019.csv

# %%
#merging data
all_data = pd.DataFrame()
for file in files:
  df = pd.read_csv('/content/Data-Science----Sales-Analytic/dataset/'+file)
  all_data = pd.concat([all_data, df])
all_data
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       162009                      iPhone                1        700
# 1       162009    Lightning Charging Cable                1      14.95
# 2       162009            Wired Headphones                2      11.99
# 3       162010  Bose SoundSport Headphones                1      99.99
# 4       162011      34in Ultrawide Monitor                1     379.99
# ...        ...                         ...              ...        ...
# 12031   162004    Apple Airpods Headphones                1        150
# 12032   162005      AAA Batteries (4-pack)                2       2.99
# 12033   162006        USB-C Charging Cable                1      11.95
# 12034   162007        USB-C Charging Cable                1      11.95
# 12035   162008            27in FHD Monitor                1     149.99
#
#            Order Date                         Purchase Address
# 0      03/28/19 20:59          942 Church St, Austin, TX 73301
# 1      03/28/19 20:59          942 Church St, Austin, TX 73301
# 2      03/28/19 20:59          942 Church St, Austin, TX 73301
# 3      03/17/19 05:39     261 10th St, San Francisco, CA 94016
# 4      03/10/19 00:01     764 13th St, San Francisco, CA 94016
# ...               ...                                      ...
# 12031  02/12/19 22:02   227 Church St, San Francisco, CA 94016
# 12032  02/04/19 20:44  417 Jefferson St, Los Angeles, CA 90001
# 12033  02/24/19 06:31            498 8th St, Atlanta, GA 30301
# 12034  02/24/19 19:09             715 7th St, Dallas, TX 75001
# 12035  02/26/19 17:15       677 West St, Los Angeles, CA 90001
#
# [186850 rows x 6 columns]

# %%
#save all data
all_data.to_csv('final_data.csv', index=False)

# %%
df = pd.read_csv('final_data.csv')
df
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        162009                      iPhone                1        700
# 1        162009    Lightning Charging Cable                1      14.95
# 2        162009            Wired Headphones                2      11.99
# 3        162010  Bose SoundSport Headphones                1      99.99
# 4        162011      34in Ultrawide Monitor                1     379.99
# ...         ...                         ...              ...        ...
# 186845   162004    Apple Airpods Headphones                1        150
# 186846   162005      AAA Batteries (4-pack)                2       2.99
# 186847   162006        USB-C Charging Cable                1      11.95
# 186848   162007        USB-C Charging Cable                1      11.95
# 186849   162008            27in FHD Monitor                1     149.99
#
#             Order Date                         Purchase Address
# 0       03/28/19 20:59          942 Church St, Austin, TX 73301
# 1       03/28/19 20:59          942 Church St, Austin, TX 73301
# 2       03/28/19 20:59          942 Church St, Austin, TX 73301
# 3       03/17/19 05:39     261 10th St, San Francisco, CA 94016
# 4       03/10/19 00:01     764 13th St, San Francisco, CA 94016
# ...                ...                                      ...
# 186845  02/12/19 22:02   227 Church St, San Francisco, CA 94016
# 186846  02/04/19 20:44  417 Jefferson St, Los Angeles, CA 90001
# 186847  02/24/19 06:31            498 8th St, Atlanta, GA 30301
# 186848  02/24/19 19:09             715 7th St, Dallas, TX 75001
# 186849  02/26/19 17:15       677 West St, Los Angeles, CA 90001
#
# [186850 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 186850 entries, 0 to 186849
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          186305 non-null  object
#  1   Product           186305 non-null  object
#  2   Quantity Ordered  186305 non-null  object
#  3   Price Each        186305 non-null  object
#  4   Order Date        186305 non-null  object
#  5   Purchase Address  186305 non-null  object
# dtypes: object(6)
# memory usage: 8.6+ MB

# %%
df.describe()
# Out:
#         Order ID               Product Quantity Ordered Price Each  \
# count     186305                186305           186305     186305
# unique    178438                    20               10         24
# top     Order ID  USB-C Charging Cable                1      11.95
# freq         355                 21903           168552      21903
#
#         Order Date  Purchase Address
# count       186305            186305
# unique      142396            140788
# top     Order Date  Purchase Address
# freq           355               355

# %%
#change the column name for easily read

df.rename(columns={"Order ID": "order_id","Product":'product','Quantity Ordered':'quantity','Price Each':'price','Order Date':'date', 'Purchase Address':'address'}, inplace=True)

# %%
#drop some unnecesarry value
df = df.drop(df[df['order_id'] == 'Order ID'].index)

# %%
#clean data
null = df[df.isna().any(axis=1)]
null.head()
# Out:
#      order_id product quantity price date address
# 1047      NaN     NaN      NaN   NaN  NaN     NaN
# 1542      NaN     NaN      NaN   NaN  NaN     NaN
# 1653      NaN     NaN      NaN   NaN  NaN     NaN
# 2014      NaN     NaN      NaN   NaN  NaN     NaN
# 2043      NaN     NaN      NaN   NaN  NaN     NaN

# %%
df = df.dropna(how='all')
df
# Out:
#        order_id                     product quantity   price            date  \
# 0        162009                      iPhone        1     700  03/28/19 20:59
# 1        162009    Lightning Charging Cable        1   14.95  03/28/19 20:59
# 2        162009            Wired Headphones        2   11.99  03/28/19 20:59
# 3        162010  Bose SoundSport Headphones        1   99.99  03/17/19 05:39
# 4        162011      34in Ultrawide Monitor        1  379.99  03/10/19 00:01
# ...         ...                         ...      ...     ...             ...
# 186845   162004    Apple Airpods Headphones        1     150  02/12/19 22:02
# 186846   162005      AAA Batteries (4-pack)        2    2.99  02/04/19 20:44
# 186847   162006        USB-C Charging Cable        1   11.95  02/24/19 06:31
# 186848   162007        USB-C Charging Cable        1   11.95  02/24/19 19:09
# 186849   162008            27in FHD Monitor        1  149.99  02/26/19 17:15
#
#                                         address
# 0               942 Church St, Austin, TX 73301
# 1               942 Church St, Austin, TX 73301
# 2               942 Church St, Austin, TX 73301
# 3          261 10th St, San Francisco, CA 94016
# 4          764 13th St, San Francisco, CA 94016
# ...                                         ...
# 186845   227 Church St, San Francisco, CA 94016
# 186846  417 Jefferson St, Los Angeles, CA 90001
# 186847            498 8th St, Atlanta, GA 30301
# 186848             715 7th St, Dallas, TX 75001
# 186849       677 West St, Los Angeles, CA 90001
#
# [185950 rows x 6 columns]

# %%
#change typedata
df['quantity'] = pd.to_numeric(df['quantity']) #change to numerical
df['price'] = pd.to_numeric(df['price']) #change to numerical

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 185950 entries, 0 to 186849
# Data columns (total 6 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   order_id  185950 non-null  object
#  1   product   185950 non-null  object
#  2   quantity  185950 non-null  int64
#  3   price     185950 non-null  float64
#  4   date      185950 non-null  object
#  5   address   185950 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 9.9+ MB

# %%
#add additional sales column
df['sales'] = df['quantity']*df['price'] #sales

# %%
#breakdwon some date in to date, month, year, hour
df['month'] = df['date'].str[0:2]
df['month'] = df['month'].astype('int32')
df['year'] = '20'+df['date'].str[6:8]
df['year'] = df['year'].astype('int32')
df['day'] = df['date'].str[3:5]
df['day'] = df['day'].astype('int32')
df['hour'] = df['date'].str[9:11]
df['hour'] = df['hour'].astype('int32')
df

#second way to get time
#df['date'] = pd.to_datetime(df['date'])
#df['hour'] = df['date'].dt.hour
# Out:
#        order_id                     product  quantity   price            date  \
# 0        162009                      iPhone         1  700.00  03/28/19 20:59
# 1        162009    Lightning Charging Cable         1   14.95  03/28/19 20:59
# 2        162009            Wired Headphones         2   11.99  03/28/19 20:59
# 3        162010  Bose SoundSport Headphones         1   99.99  03/17/19 05:39
# 4        162011      34in Ultrawide Monitor         1  379.99  03/10/19 00:01
# ...         ...                         ...       ...     ...             ...
# 186845   162004    Apple Airpods Headphones         1  150.00  02/12/19 22:02
# 186846   162005      AAA Batteries (4-pack)         2    2.99  02/04/19 20:44
# 186847   162006        USB-C Charging Cable         1   11.95  02/24/19 06:31
# 186848   162007        USB-C Charging Cable         1   11.95  02/24/19 19:09
# 186849   162008            27in FHD Monitor         1  149.99  02/26/19 17:15
#
#                                         address   sales  month  year  day  \
# 0               942 Church St, Austin, TX 73301  700.00      3  2019   28
# 1               942 Church St, Austin, TX 73301   14.95      3  2019   28
# 2               942 Church St, Austin, TX 73301   23.98      3  2019   28
# 3          261 10th St, San Francisco, CA 94016   99.99      3  2019   17
# 4          764 13th St, San Francisco, CA 94016  379.99      3  2019   10
# ...                                         ...     ...    ...   ...  ...
# 186845   227 Church St, San Francisco, CA 94016  150.00      2  2019   12
# 186846  417 Jefferson St, Los Angeles, CA 90001    5.98      2  2019    4
# 186847            498 8th St, Atlanta, GA 30301   11.95      2  2019   24
# 186848             715 7th St, Dallas, TX 75001   11.95      2  2019   24
# 186849       677 West St, Los Angeles, CA 90001  149.99      2  2019   26
#
#         hour
# 0         20
# 1         20
# 2         20
# 3          5
# 4          0
# ...      ...
# 186845    22
# 186846    20
# 186847     6
# 186848    19
# 186849    17
#
# [185950 rows x 11 columns]

# %%
#breakdown address into city and state
#df['city'] = df['address'].str.split(',').str[1]
df['state'] = df['address'].str.split(',').str[2]
df['state'] = df['state'].str.split(' ').str[1]
#df

#way2
def get_city(addres):
  return addres.split(',')[1]
def get_state(addres):
  return addres.split(',')[2].split(' ')[1]

#df['City'] = df['address'].apply(lambda x: get_city(x) + ' ' + get_state(x))
df['city'] = df['address'].apply(lambda x: f"{get_city(x)} ({get_state(x)})")
df
# Out:
#        order_id                     product  quantity   price            date  \
# 0        162009                      iPhone         1  700.00  03/28/19 20:59
# 1        162009    Lightning Charging Cable         1   14.95  03/28/19 20:59
# 2        162009            Wired Headphones         2   11.99  03/28/19 20:59
# 3        162010  Bose SoundSport Headphones         1   99.99  03/17/19 05:39
# 4        162011      34in Ultrawide Monitor         1  379.99  03/10/19 00:01
# ...         ...                         ...       ...     ...             ...
# 186845   162004    Apple Airpods Headphones         1  150.00  02/12/19 22:02
# 186846   162005      AAA Batteries (4-pack)         2    2.99  02/04/19 20:44
# 186847   162006        USB-C Charging Cable         1   11.95  02/24/19 06:31
# 186848   162007        USB-C Charging Cable         1   11.95  02/24/19 19:09
# 186849   162008            27in FHD Monitor         1  149.99  02/26/19 17:15
#
#                                         address   sales  month  year  day  \
# 0               942 Church St, Austin, TX 73301  700.00      3  2019   28
# 1               942 Church St, Austin, TX 73301   14.95      3  2019   28
# 2               942 Church St, Austin, TX 73301   23.98      3  2019   28
# 3          261 10th St, San Francisco, CA 94016   99.99      3  2019   17
# 4          764 13th St, San Francisco, CA 94016  379.99      3  2019   10
# ...                                         ...     ...    ...   ...  ...
# 186845   227 Church St, San Francisco, CA 94016  150.00      2  2019   12
# 186846  417 Jefferson St, Los Angeles, CA 90001    5.98      2  2019    4
# 186847            498 8th St, Atlanta, GA 30301   11.95      2  2019   24
# 186848             715 7th St, Dallas, TX 75001   11.95      2  2019   24
# 186849       677 West St, Los Angeles, CA 90001  149.99      2  2019   26
#
#         hour                 city state
# 0         20          Austin (TX)    TX
# 1         20          Austin (TX)    TX
# 2         20          Austin (TX)    TX
# 3          5   San Francisco (CA)    CA
# 4          0   San Francisco (CA)    CA
# ...      ...                  ...   ...
# 186845    22   San Francisco (CA)    CA
# 186846    20     Los Angeles (CA)    CA
# 186847     6         Atlanta (GA)    GA
# 186848    19          Dallas (TX)    TX
# 186849    17     Los Angeles (CA)    CA
#
# [185950 rows x 13 columns]

# %%
#identifier state
df['state']=df['state'].replace(regex={r'TX': 'Texas', 'CA': 'California','MA':'Massachusetts','GA':'Georgia','OR':'Oregon','NY':'New York','WA':'Washington','ME':'Maine'})
df
# Out:
#        order_id                     product  quantity   price            date  \
# 0        162009                      iPhone         1  700.00  03/28/19 20:59
# 1        162009    Lightning Charging Cable         1   14.95  03/28/19 20:59
# 2        162009            Wired Headphones         2   11.99  03/28/19 20:59
# 3        162010  Bose SoundSport Headphones         1   99.99  03/17/19 05:39
# 4        162011      34in Ultrawide Monitor         1  379.99  03/10/19 00:01
# ...         ...                         ...       ...     ...             ...
# 186845   162004    Apple Airpods Headphones         1  150.00  02/12/19 22:02
# 186846   162005      AAA Batteries (4-pack)         2    2.99  02/04/19 20:44
# 186847   162006        USB-C Charging Cable         1   11.95  02/24/19 06:31
# 186848   162007        USB-C Charging Cable         1   11.95  02/24/19 19:09
# 186849   162008            27in FHD Monitor         1  149.99  02/26/19 17:15
#
#                                         address   sales  month  year  day  \
# 0               942 Church St, Austin, TX 73301  700.00      3  2019   28
# 1               942 Church St, Austin, TX 73301   14.95      3  2019   28
# 2               942 Church St, Austin, TX 73301   23.98      3  2019   28
# 3          261 10th St, San Francisco, CA 94016   99.99      3  2019   17
# 4          764 13th St, San Francisco, CA 94016  379.99      3  2019   10
# ...                                         ...     ...    ...   ...  ...
# 186845   227 Church St, San Francisco, CA 94016  150.00      2  2019   12
# 186846  417 Jefferson St, Los Angeles, CA 90001    5.98      2  2019    4
# 186847            498 8th St, Atlanta, GA 30301   11.95      2  2019   24
# 186848             715 7th St, Dallas, TX 75001   11.95      2  2019   24
# 186849       677 West St, Los Angeles, CA 90001  149.99      2  2019   26
#
#         hour                 city       state
# 0         20          Austin (TX)       Texas
# 1         20          Austin (TX)       Texas
# 2         20          Austin (TX)       Texas
# 3          5   San Francisco (CA)  California
# 4          0   San Francisco (CA)  California
# ...      ...                  ...         ...
# 186845    22   San Francisco (CA)  California
# 186846    20     Los Angeles (CA)  California
# 186847     6         Atlanta (GA)     Georgia
# 186848    19          Dallas (TX)       Texas
# 186849    17     Los Angeles (CA)  California
#
# [185950 rows x 13 columns]

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
#save fixed data
df.to_csv('fixed.csv', index=False)

# %%
# Question 1 : What was the best month for sales ? How much was earned that month?
monthly = df.groupby('month')[['quantity','sales']].sum()
monthly = monthly.reset_index()
monthly['month'] = monthly['month'].apply(lambda x: calendar.month_name[x])
monthly
# Out:
#         month  quantity       sales
# 0     January     10903  1822256.73
# 1    February     13449  2202022.42
# 2       March     17005  2807100.38
# 3       April     20558  3390670.24
# 4         May     18667  3152606.75
# 5        June     15253  2577802.26
# 6        July     16072  2647775.76
# 7      August     13448  2244467.88
# 8   September     13109  2097560.13
# 9     October     22703  3736726.88
# 10   November     19798  3199603.20
# 11   December     28114  4613443.34

# %%
plt.figure(figsize=(12,5))
plt.bar(monthly['month'], monthly['sales'])
plt.xticks(monthly['month'], size=8)
plt.xlabel('Month')
plt.ylabel('Sales in $USD (million)')
plt.show()

# %%
# Question 2 : How many product sold every month

#visualization
plt.plot(monthly['month'], monthly['quantity'])
plt.xticks(monthly['month'], rotation='vertical')
plt.ylabel('Product Sold')
plt.xlabel('Month Number')
plt.show()

# %%
#Question 3 : What city had the highest number of sales
sales_city = df.groupby('city').sum()
sales_city = sales_city.reset_index()
sales_city
# Out:
# <ipython-input-28-b2317b4d679f>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sales_city = df.groupby('city').sum()
#                   city  quantity       price       sales   month      year  \
# 0         Atlanta (GA)     16602  2779908.20  2795498.58  104794  30044739
# 1          Austin (TX)     11153  1809873.61  1819581.75   69829  19998197
# 2          Boston (MA)     22528  3637409.77  3661642.01  141112  40246750
# 3          Dallas (TX)     16730  2752627.82  2767975.40  104620  29921582
# 4     Los Angeles (CA)     33289  5421435.23  5452570.80  208325  59772496
# 5   New York City (NY)     27932  4635370.83  4664317.43  175741  50224654
# 6        Portland (ME)      2750   447189.25   449758.27   17144   4956645
# 7        Portland (OR)     11303  1860558.22  1870732.34   70621  20210192
# 8   San Francisco (CA)     50239  8211461.74  8262203.91  315520  90313920
# 9         Seattle (WA)     16553  2733296.01  2747755.48  104941  29743909
#
#       day    hour
# 0  234837  214264
# 1  156782  141946
# 2  312376  288225
# 3  234435  214390
# 4  469607  427444
# 5  392706  357696
# 6   38288   35211
# 7  159233  144421
# 8  702669  643265
# 9  229552  213292

# %%
#visualization
plt.figure(figsize=(8,5))
plt.bar(sales_city['city'], sales_city['sales'])
plt.xticks(sales_city['city'], rotation='vertical')
plt.xlabel('City')
plt.ylabel('Sales in $USD (million)')
plt.show()

# %%
#Question 4 : What state had the highest number of sales
states = df.groupby('state').sum()
states = states.reset_index()
states
# Out:
# <ipython-input-30-9ca4ad862aed>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   states = df.groupby('state').sum()
#            state  quantity        price        sales   month       year  \
# 0     California     83528  13632896.97  13714774.71  523845  150086416
# 1        Georgia     16602   2779908.20   2795498.58  104794   30044739
# 2          Maine      2750    447189.25    449758.27   17144    4956645
# 3  Massachusetts     22528   3637409.77   3661642.01  141112   40246750
# 4       New York     27932   4635370.83   4664317.43  175741   50224654
# 5         Oregon     11303   1860558.22   1870732.34   70621   20210192
# 6          Texas     27883   4562501.43   4587557.15  174449   49919779
# 7     Washington     16553   2733296.01   2747755.48  104941   29743909
#
#        day     hour
# 0  1172276  1070709
# 1   234837   214264
# 2    38288    35211
# 3   312376   288225
# 4   392706   357696
# 5   159233   144421
# 6   391217   356336
# 7   229552   213292

# %%
#visuzlization
plt.figure(figsize=(8,5))
plt.bar(states['state'], states['sales'])
plt.xticks(states['state'], rotation='vertical')
plt.xlabel('State')
plt.ylabel('Sales in $USD (million)')
plt.show()

# %%
#Question 5 : What time should we push our advertising to maximize our potential customers buying our product
hoursales = df.groupby('hour').sum()
hoursales = hoursales.reset_index()
hoursales
# Out:
# <ipython-input-32-0a322f966174>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   hoursales = df.groupby('hour').sum()
#     hour  quantity       price       sales  month      year     day
# 0      0      4428   709296.70   713721.27  27554   7894302   62015
# 1      1      2619   458490.00   460866.88  16657   4744659   37333
# 2      2      1398   233833.64   234851.44   8507   2509621   19631
# 3      3       928   144726.42   145757.89   5904   1677792   13430
# 4      4       937   162058.18   162661.01   6148   1724230   13756
# 5      5      1493   229621.21   230679.82   9301   2667101   21347
# 6      6      2810   445000.11   448113.00  17539   5011158   39824
# 7      7      4556   740568.11   744854.12  28850   8098209   63111
# 8      8      7002  1185970.62  1192348.97  43626  12630864   98078
# 9      9      9816  1628498.49  1639030.58  60981  17662212  137512
# 10    10     12308  1932665.62  1944286.77  76928  22095936  173128
# 11    11     14005  2288855.18  2300610.24  87654  25057809  195901
# 12    12     14202  2299876.68  2316821.34  89161  25413153  197231
# 13    13     13685  2139743.86  2155389.80  85808  24488451  190415
# 14    14     12362  2072194.77  2083672.73  77836  22176696  173264
# 15    15     11391  1931174.99  1941549.60  72060  20543325  161441
# 16    16     11662  1892454.54  1904601.31  72939  20965296  162579
# 17    17     12229  2116777.02  2129361.61  77454  22005081  169311
# 18    18     13802  2207696.93  2219348.30  86421  24793320  194087
# 19    19     14470  2398588.31  2412938.54  91389  26055195  205868
# 20    20     13768  2268185.16  2281716.24  86375  24688332  192147
# 21    21     12244  2030763.83  2042000.86  77103  22049499  171214
# 22    22      9899  1599464.44  1607549.21  62088  17811618  138981
# 23    23      7065  1172625.87  1179304.44  44364  12669225   98881

# %%
hours = [hour for hour, df in df.groupby('hour')]

plt.plot(hoursales['hour'], hoursales['sales'])
plt.xticks(hoursales['hour'], rotation='vertical')
plt.grid()
plt.xlabel('Hour')
plt.ylabel('Sales in $USD (million)')
plt.show()

# %%
#Question 6 : Whats product are most often sold together ?
df_c = df[df['order_id'].duplicated(keep=False)]
df_c['group'] = df.groupby('order_id')['product'].transform(lambda x: ','.join(x))
df_c = df_c[['order_id','group']].drop_duplicates()
df_c
# Out:
# <ipython-input-34-c8efb230dd8c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_c['group'] = df.groupby('order_id')['product'].transform(lambda x: ','.join(x))
#        order_id                                              group
# 0        162009   iPhone,Lightning Charging Cable,Wired Headphones
# 30       162037                    iPhone,Lightning Charging Cable
# 60       162066         AA Batteries (4-pack),USB-C Charging Cable
# 66       162071               Vareebadd Phone,USB-C Charging Cable
# 78       162082                   Vareebadd Phone,Wired Headphones
# ...         ...                                                ...
# 186754   161920  Google Phone,USB-C Charging Cable,AAA Batterie...
# 186781   161945        USB-C Charging Cable,34in Ultrawide Monitor
# 186798   161960               Vareebadd Phone,USB-C Charging Cable
# 186811   161972                  Google Phone,USB-C Charging Cable
# 186837   161997                  Google Phone,USB-C Charging Cable
#
# [7136 rows x 2 columns]

# %%
from itertools import combinations
from collections import Counter

count = Counter()

for row in df_c['group']:
  row_list = row.split(',')
  count.update(Counter(combinations(row_list, 2)))

#for key, value in count.most_common(10):
#  print(key, value)

# Get the top 10 combinations and their counts
top_combinations = dict(count.most_common(10))

# Separate the combinations and counts for plotting
combinations, counts = zip(*top_combinations.items())

# Convert combinations to strings
combinations = [str(comb) for comb in combinations]

# Sort in descending order
combinations, counts = zip(*sorted(zip(combinations, counts), key=lambda x: x[1], reverse=False))


plt.barh(combinations, counts)
plt.xlabel('Product Group')
plt.ylabel('Count Order')
plt.show()

# %%
#Question 7 : What product sold most ? Why do you think it most ?

product_gr = df.groupby('product').sum()
product_gr = product_gr.reset_index()
product_gr
# Out:
# <ipython-input-36-6a5c5d028af9>:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   product_gr = df.groupby('product').sum()
#                        product  quantity       price       sales   month  \
# 0                 20in Monitor      4129   451068.99   454148.71   29336
# 1       27in 4K Gaming Monitor      6244  2429637.70  2435097.56   44440
# 2             27in FHD Monitor      7550  1125974.93  1132424.50   52558
# 3       34in Ultrawide Monitor      6199  2348718.19  2355558.01   43304
# 4        AA Batteries (4-pack)     27635    79015.68   106118.40  145558
# 5       AAA Batteries (4-pack)     31017    61716.59    92740.83  146370
# 6     Apple Airpods Headphones     15661  2332350.00  2349150.00  109477
# 7   Bose SoundSport Headphones     13457  1332366.75  1345565.43   94113
# 8                Flatscreen TV      4819  1440000.00  1445700.00   34224
# 9                 Google Phone      5532  3315000.00  3319200.00   38305
# 10                    LG Dryer       646   387600.00   387600.00    4383
# 11          LG Washing Machine       666   399600.00   399600.00    4523
# 12    Lightning Charging Cable     23217   323787.10   347094.15  153092
# 13          Macbook Pro Laptop      4728  8030800.00  8037600.00   33548
# 14             ThinkPad Laptop      4130  4127958.72  4129958.70   28950
# 15        USB-C Charging Cable     23975   261740.85   286501.25  154819
# 16             Vareebadd Phone      2068   826000.00   827200.00   14309
# 17            Wired Headphones     20557   226395.18   246478.43  133397
# 18                      iPhone      6849  4789400.00  4794300.00   47941
#
#         year     day    hour
# 0    8279921   64237   58764
# 1   12578371   97624   90916
# 2   15156636  117702  107540
# 3   12479439   97726   89076
# 4   41544963  325504  298342
# 5   41674182  326283  297332
# 6   31393435  244828  223304
# 7   26903178  210543  192445
# 8    9691201   75959   68815
# 9   11154976   86444   79479
# 10   1304274   10071    9326
# 11   1344654   10323    9785
# 12  43727507  341405  312529
# 13   9537757   74428   68261
# 14   8334434   64351   59746
# 15  44222161  345452  314645
# 16   4169236   32733   29472
# 17  38122759  297276  271720
# 18  13814000  107596   98657

# %%
prices = df.groupby('product')['price'].mean()
prices
# Out:
# product
# 20in Monitor                   109.99
# 27in 4K Gaming Monitor         389.99
# 27in FHD Monitor               149.99
# 34in Ultrawide Monitor         379.99
# AA Batteries (4-pack)            3.84
# AAA Batteries (4-pack)           2.99
# Apple Airpods Headphones       150.00
# Bose SoundSport Headphones      99.99
# Flatscreen TV                  300.00
# Google Phone                   600.00
# LG Dryer                       600.00
# LG Washing Machine             600.00
# Lightning Charging Cable        14.95
# Macbook Pro Laptop            1700.00
# ThinkPad Laptop                999.99
# USB-C Charging Cable            11.95
# Vareebadd Phone                400.00
# Wired Headphones                11.99
# iPhone                         700.00
# Name: price, dtype: float64

# %%
#visuzlization
fig, ax1 = plt.subplots()

ax2 = ax1.twinx()
ax1.bar(product_gr['product'], product_gr['quantity'])
ax2.plot(product_gr['product'], prices, 'b-')

ax1.set_xlabel('Product Name')
ax1.set_ylabel('Quantity Order')
ax1.set_xticklabels(product_gr['product'], rotation='vertical')
ax2.set_ylabel('Prices')
plt.show()
# Out:
# <ipython-input-38-4298e73e72a8>:10: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(product_gr['product'], rotation='vertical')

# %%
#Cause of issue from delimeter decimal, i want to change the dot(.) from price and sales with coma (,)
df_test = df
df_test
# Out:
#        order_id                     product  quantity   price  \
# 0        162009                      iPhone         1  700.00
# 1        162009    Lightning Charging Cable         1   14.95
# 2        162009            Wired Headphones         2   11.99
# 3        162010  Bose SoundSport Headphones         1   99.99
# 4        162011      34in Ultrawide Monitor         1  379.99
# ...         ...                         ...       ...     ...
# 186845   162004    Apple Airpods Headphones         1  150.00
# 186846   162005      AAA Batteries (4-pack)         2    2.99
# 186847   162006        USB-C Charging Cable         1   11.95
# 186848   162007        USB-C Charging Cable         1   11.95
# 186849   162008            27in FHD Monitor         1  149.99
#
#                       date                                  address   sales  \
# 0      2019-03-28 20:59:00          942 Church St, Austin, TX 73301  700.00
# 1      2019-03-28 20:59:00          942 Church St, Austin, TX 73301   14.95
# 2      2019-03-28 20:59:00          942 Church St, Austin, TX 73301   23.98
# 3      2019-03-17 05:39:00     261 10th St, San Francisco, CA 94016   99.99
# 4      2019-03-10 00:01:00     764 13th St, San Francisco, CA 94016  379.99
# ...                    ...                                      ...     ...
# 186845 2019-02-12 22:02:00   227 Church St, San Francisco, CA 94016  150.00
# 186846 2019-02-04 20:44:00  417 Jefferson St, Los Angeles, CA 90001    5.98
# 186847 2019-02-24 06:31:00            498 8th St, Atlanta, GA 30301   11.95
# 186848 2019-02-24 19:09:00             715 7th St, Dallas, TX 75001   11.95
# 186849 2019-02-26 17:15:00       677 West St, Los Angeles, CA 90001  149.99
#
#         month  year  day  hour                 city       state
# 0           3  2019   28    20          Austin (TX)       Texas
# 1           3  2019   28    20          Austin (TX)       Texas
# 2           3  2019   28    20          Austin (TX)       Texas
# 3           3  2019   17     5   San Francisco (CA)  California
# 4           3  2019   10     0   San Francisco (CA)  California
# ...       ...   ...  ...   ...                  ...         ...
# 186845      2  2019   12    22   San Francisco (CA)  California
# 186846      2  2019    4    20     Los Angeles (CA)  California
# 186847      2  2019   24     6         Atlanta (GA)     Georgia
# 186848      2  2019   24    19          Dallas (TX)       Texas
# 186849      2  2019   26    17     Los Angeles (CA)  California
#
# [185950 rows x 13 columns]

# %%
#Cause when we want to change the delimeter, lets change datatype from price and sales
df_test['sales'] = df_test['sales'].astype('string')
df_test['price'] = df_test['price'].astype('string')
df_test
# Out:
#        order_id                     product  quantity   price  \
# 0        162009                      iPhone         1   700,0
# 1        162009    Lightning Charging Cable         1   14,95
# 2        162009            Wired Headphones         2   11,99
# 3        162010  Bose SoundSport Headphones         1   99,99
# 4        162011      34in Ultrawide Monitor         1  379,99
# ...         ...                         ...       ...     ...
# 186845   162004    Apple Airpods Headphones         1   150,0
# 186846   162005      AAA Batteries (4-pack)         2    2,99
# 186847   162006        USB-C Charging Cable         1   11,95
# 186848   162007        USB-C Charging Cable         1   11,95
# 186849   162008            27in FHD Monitor         1  149,99
#
#                       date                                  address   sales  \
# 0      2019-03-28 20:59:00          942 Church St, Austin, TX 73301   700.0
# 1      2019-03-28 20:59:00          942 Church St, Austin, TX 73301   14.95
# 2      2019-03-28 20:59:00          942 Church St, Austin, TX 73301   23.98
# 3      2019-03-17 05:39:00     261 10th St, San Francisco, CA 94016   99.99
# 4      2019-03-10 00:01:00     764 13th St, San Francisco, CA 94016  379.99
# ...                    ...                                      ...     ...
# 186845 2019-02-12 22:02:00   227 Church St, San Francisco, CA 94016   150.0
# 186846 2019-02-04 20:44:00  417 Jefferson St, Los Angeles, CA 90001    5.98
# 186847 2019-02-24 06:31:00            498 8th St, Atlanta, GA 30301   11.95
# 186848 2019-02-24 19:09:00             715 7th St, Dallas, TX 75001   11.95
# 186849 2019-02-26 17:15:00       677 West St, Los Angeles, CA 90001  149.99
#
#         month  year  day  hour                 city       state
# 0           3  2019   28    20          Austin (TX)       Texas
# 1           3  2019   28    20          Austin (TX)       Texas
# 2           3  2019   28    20          Austin (TX)       Texas
# 3           3  2019   17     5   San Francisco (CA)  California
# 4           3  2019   10     0   San Francisco (CA)  California
# ...       ...   ...  ...   ...                  ...         ...
# 186845      2  2019   12    22   San Francisco (CA)  California
# 186846      2  2019    4    20     Los Angeles (CA)  California
# 186847      2  2019   24     6         Atlanta (GA)     Georgia
# 186848      2  2019   24    19          Dallas (TX)       Texas
# 186849      2  2019   26    17     Los Angeles (CA)  California
#
# [185950 rows x 13 columns]

# %%
#change delimeter
df_test['sales'] = [x.replace('.', ',') for x in df['sales']]
df_test['price'] = [x.replace('.', ',') for x in df['price']]

# %%
df_test.to_csv('fixed.csv', index=False)
